# %%
from collections import Counter
from vectors import distance
import random 
import matplotlib.pyplot as plt
from collections import defaultdict
from statistic import mean
import math
import glob,re

# %% [markdown]
# ## Naive Bayes

# %%
def tokenize(message):
    message = message.lower()
    all_words = re.findall('[a-z0-9]+',message)
    return set(all_words)


def count_words(training_set):
    counts = defaultdict(lambda: [0,0])

    for message, is_spam in training_set:
        for word in tokenize(message):
            counts[word][0 if is_spam else 1] += 1

    return counts

def words_probabilites(counts, total_spams, total_non_spams, k=0.5):
    return [(w,((spam+k)/(total_spams + 2*k)),((non_spam + k)/(total_non_spams + 2*k))) 
            for w,(spam,non_spam) in counts.items()]

def spam_probability(word_props,message):
    message_words = tokenize(message)
    log_prop_if_spam = log_prop_if_not_spam = 0

    for word, prob_if_spam, prob_if_not_spam in word_props:
        
        if word in message_words:
            log_prop_if_spam += math.log(prob_if_spam) 
            log_prop_if_not_spam += math.log(prob_if_not_spam)
        else:
            log_prop_if_spam += math.log(1-prob_if_spam) 
            log_prop_if_not_spam += math.log(1-prob_if_not_spam)


    prob_if_spam = math.exp(log_prop_if_spam)
    prob_if_not_spam = math.exp(log_prop_if_not_spam)

    return prob_if_spam/(prob_if_spam + prob_if_not_spam)

# %%
class NaiveBayesClassifier: 
    def __init__(self, k=0.5):
        self.k = k
        self.word_props = []

    def train(self, training_set):

        num_spams = len([message for message,is_spam in training_set if is_spam])
        num_non_spams = len(training_set) - num_spams 

        word_counts = count_words(training_set)

        self.word_props = words_probabilites(word_counts,num_spams,num_non_spams,self.k)

    def classify(self,message):
        return spam_probability(self.word_props, message)

# %%
path = r"spam\*"

data = []

for fn in glob.glob('spam/*/*'):
    is_spam = 'ham' not in fn
    try:
        with open(fn,'r') as file:
            for line in file:
                if line.startswith("Subject:"):
                    subject = re.sub(r"^Subject: ", "", line).strip()
                    data.append((subject, is_spam))
                    break
    except:
        pass 
        #print(f'erro ao abrir arquivo: {fn}')

print(len(data))
# Out:
# 3074

# %%
def split_data(data, prop):
    results = [[],[]]

    for num in data:
        results[0 if random.random() < prop else 1].append(num)

    return results

# %%
random.seed(0)

train_data, test_data = split_data(data, 0.75)

classifier = NaiveBayesClassifier()

classifier.train(train_data)


classified = [(subject, is_spam, classifier.classify(subject)) for subject, is_spam in test_data]

counts = Counter((is_spam,spam_probability > 0.5) for _,is_spam,spam_probability in classified)

counts.most_common()
# Out:
# [((False, False), 648),
#  ((True, True), 69),
#  ((True, False), 35),
#  ((False, True), 22)]

# %%
classified.sort(key=lambda row:row[2], reverse=True)
classified
# Out:
# [('MSNBC: Rates Hit 18 year Low 4.75% ...28940', True, 0.9999999941001101),
#  ('Last time you spent $25 did u make $100,000,s? Well this time you will. wju',
#   True,
#   0.999999988485202),
#  ('HOME REPS WANTED-FORTUNE 500 COMP HIRING', True, 0.9999999761928421),
#  ('FORTUNE 500 WORK AT HOME REPS NEEDED!', True, 0.9999998981122058),
#  ('Order your Viagra and weight-loss here 6117kFvc5--9',
#   True,
#   0.9999998900992519),
#  ('Fw: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!DGYWAOG',
#   True,
#   0.9999998655671016),
#  ('ADV: Lowest life insurance rates available!                                                   moode',
#   True,
#   0.9999997977148453),
#  ('[ILUG] Earn 100.000$ in one year working at home',
#   True,
#   0.9999996140424159),
#  ('ADV: Extended Auto Warranties Here hvgxs', True, 0.9999990779082213),
#  ('International calls for only 33 cents per minute with no subscription',
#   True,
#   0.9999974955038126),
#  ('[ILUG] Guaranteed to lose 10-12 lbs in 30 days 10.206',
#   True,
#   0.9999968704592087),
#  ("don't proscrastinate...it's only $14.95 per year",
#   True,
#   0.9999959423690549),
#  ('Re: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!    COXR',
#   True,
#   0.9999927342502565),
#  ('Conference calls/best quality/$.18 per minute!', True, 0.9999900692706644),
#  ("[ILUG] Join the Web's Fastest Growing Singles Community 11.67",
#   True,
#   0.999984799013612),
#  ('Lenders WILL COMPETE for your mortgage             IVX',
#   True,
#   0.9999818433258432),
#  ('3 Cd Package: 300 Million Email Addresses + 1.5 Mil Fax Numbers $99.95',
#   True,
#   0.999978331198562),
#  ('Guaranteed to lose 10-12 lbs in 30 days with Slim Patch                    10.24',
#   True,
#   0.9999773871062975),
#  ('zzzz, do we have your money?', True, 0.9999748171932252),
#  ('$14.95 per year domain names', True, 0.9999714061582299),
#  ('Hey, rates are low. What are you waiting for?', True, 0.9999703169131509),
#  ('Best Life Insurance, Lowest Cost...           NTICY',
#   True,
#   0.9999651407591178),
#  ('Attn: NORTON SYSTEMWORKS 2002 BLOWOUT!                 QHZHC',
#   True,
#   0.9998700077911493),
#  ('Hosting from ?6.50 per month', True, 0.9996026934886157),
#  ('Re: PROTECT YOUR COMPUTER AGAINST HARMFUL VIRUSES! 21198',
#   True,
#   0.999299891381587),
#  ('Market Internet Access - No Investment Needed', True, 0.999132224162925),
#  ("Don't get caught by rising interest rates.", True, 0.9985223159005192),
#  ('HELP WANTED.  WORK FROM HOME REPS.', True, 0.9983225497593826),
#  ('Four free e-mailers reviewed, Get the gear you need to burn DVDs',
#   False,
#   0.997801564798265),
#  ('Attn:Targeted email addresses', True, 0.9971100884779862),
#  ('Get the Child Support You Deserve                            11.180',
#   True,
#   0.9970933106815265),
#  ('Get the Child Support You Deserve                      10.124',
#   True,
#   0.9970067882299246),
#  ('Everybody Gets Paid - No Recruiting Needed', True, 0.9966871178125772),
#  ('link to my webcam you wanted', True, 0.9953993036935429),
#  ('Interest Rates at Forty Yr. Lows', True, 0.9953679535310821),
#  ('=?iso-8859-1?Q?Matrox_Parhelia=99_now_available?=',
#   False,
#   0.9948287637785452),
#  ('=?iso-2022-jp?B?GyRCRnxLXDhsJE43b0w+IUolNSVWJTglJyUvJUghSyEhJTkbKEI=?=',
#   False,
#   0.9947031438788821),
#  ('The MIME information you requested (last changed 3154 Feb 14)',
#   False,
#   0.9933650272306319),
#  ("Right-wing governments 'increase suicide rates'",
#   False,
#   0.9926639555254675),
#  ('Half Price Cigarettes and Tobacco', True, 0.9922644653726704),
#  ('Re:[1]Save over $70 on this exquisite software suite. FTS',
#   True,
#   0.9919938048352779),
#  ('Seeking Your Partnership', True, 0.9885142747407365),
#  ('WORK FROM HOME.  WE ARE HIRING', True, 0.9859949300522498),
#  ('Your eBay account is about to expire!', True, 0.9840762967634117),
#  ('New Stock Pick: BBAN - Last Pick UP 309%.......................................... gsg',
#   True,
#   0.9795975984713263),
#  ('[ILUG-Social] Claim Your $25 Kmart Gift Card', True, 0.976922477086931),
#  ('Play a Hilarious Phone Prank', True, 0.9755738560846042),
#  ('Life Insurance Quotes Without the Hassle...            JHIWNS',
#   True,
#   0.9735111947782716),
#  ('Low Price Tobacco', True, 0.9660083870421936),
#  ('Printer Cartridges as low as $1.21 each!', True, 0.9451532579028616),
#  ('[ILUG-Social] Need a Credit Card?', True, 0.9442989794699277),
#  ('Please help Home Entertainment Companies with Survey - Win a DVR!',
#   True,
#   0.9411952891160785),
#  ('Please help Home Entertainment Companies with Survey - Win a DVR!',
#   True,
#   0.9411952891160785),
#  ('Are bigger notebooks better?', False, 0.93320987471868),
#  ('Re: The MIME information you requested (last changed 3154 Feb 14)',
#   False,
#   0.9326828816064637),
#  ("you don't satisfy me               FGTPRIL", True, 0.9309533447210796),
#  ('[ILUG-Social] my webcam is on babe!', True, 0.9261080600046331),
#  ('[ILUG] assistance needed', True, 0.9255686394712935),
#  ('Woman finds rubber glove in hamburger bun. Will now sue',
#   False,
#   0.9082985698434354),
#  ('Space probe kit will fight terrestrial crime', False, 0.86474776027562),
#  ('!Gorgeous,Custom Websites - $399 Complete! (4156cumG9-855YQKc5@17)',
#   True,
#   0.8624022170224461),
#  ('Funds Investment', True, 0.8483580704614867),
#  ('Funds Investment', True, 0.8483580704614867),
#  ('Equitable prepares to compensate 70,000', False, 0.8381300889901481),
#  ('How Microsoft plans to take over your living room [ANCHORDESK]',
#   False,
#   0.8361193930177232),
#  ('=?big5?Q?re:=A7=DA=AA=BE=B9D=A7A=BB=DD=ADn=A7=F3=A6h=BE=F7=B7|,=A4@=B0_=A8=D3=A7a!?=',
#   True,
#   0.8019798913739412),
#  ('Cheap Fags', True, 0.799335113446758),
#  ('CAREER OPPORTUNITY.  WORK FROM HOME', True, 0.7914248379210735),
#  ('QOTD: Cigarettes, fast food, beer.', False, 0.7685853782232772),
#  ('Impaired Risk Case of the Month', True, 0.7593643333517097),
#  ('FREE SHIPPING! No Minimum Purchase* at Buy.com', False, 0.7438992747820445),
#  ('Term Insurance Is Out', True, 0.737693228449103),
#  ('A must have for "Gadget" lovers 7134-4', True, 0.7312986534614849),
#  ("Shop smarter with ZDNet's price-feature analysis",
#   False,
#   0.7234557676149714),
#  ('Best product for 2002', True, 0.704764105084997),
#  ('Business card design', False, 0.6824854719390109),
#  ('Claim a Free $25 Kmart(R) Gift Card!', True, 0.6632826976652269),
#  ('Discount Smokes', True, 0.6508241808279321),
#  ('=?Big5?B?rEKq96SjrE5+fqdPtsykRn5+?=', True, 0.6508241808279183),
#  ('[ILUG] Garden Ornaments | mvcmv', True, 0.6483499004451082),
#  ('FW: SHORT TERM BUY RECOMMENDATION', True, 0.6437090670857355),
#  ('Dear Steve Jobs: At Macworld, show me this... [ANCHORDESK]',
#   False,
#   0.6413662510106574),
#  ("Market Can't Find Its Bottom With Both Hands", False, 0.6102696133844424),
#  ("Market Can't Find Its Bottom With Both Hands", False, 0.6102696133844424),
#  ('- Custom Websites for $399 Complete! (1709D@5)', True, 0.5917864723610899),
#  ("Anarchist 'Scavenger Hunt' Raises D.C. Police Ire (fwd)",
#   False,
#   0.5780899827503797),
#  ('Incredible Pictures!!!!!!!!', True, 0.570937448393516),
#  ("You can't beat city hall", False, 0.5587597064731653),
#  ('1987 copy of Nintendo zine going for $700 on eBay',
#   False,
#   0.5438712194464026),
#  ('Life Insurance - Why Pay More?', True, 0.5181328763248267),
#  ("Second-hand sales blamed for bedbugs' comeback", False, 0.5014250121832329),
#  ('Critical breast cancer gene identified', False, 0.4899102660533223),
#  ('zzzz,Hello', True, 0.47822741874301666),
#  ('Re: Adam dont job for no one, see.', False, 0.4749639793986908),
#  ('The subtle art of sugaring bitter pills goes down well',
#   False,
#   0.4707285848861782),
#  ('More cash for the business you already write - IMMEDIATELY',
#   True,
#   0.4556920617306492),
#  ('Slim Factors - A totally new approach to weight loss',
#   True,
#   0.41904482525090014),
#  ('Find Peace, Harmony, Tranquility, And Happiness Right Now!',
#   True,
#   0.41484457420975557),
#  ('CNET Cool Gear: Find the right cordless phone', False, 0.3945796254071453),
#  ('$15,000 umbrella stand: nothing exceeds like excess',
#   False,
#   0.37886492148913853),
#  ('Meet other Singles just like you', True, 0.3250468182066893),
#  ('Whatever-Dude.com Needs $300 Quick to Get Their Freed from their ISP',
#   False,
#   0.3190215411622208),
#  ('After posting my comment yesterday about next things I want to',
#   False,
#   0.28073862550929457),
#  ('Iran Pushes UN Intervention Against US', False, 0.276771333726665),
#  ("UK 'should ban nuclear arms'", False, 0.274267512614324),
#  ('Tell these cam sluts what to do', True, 0.2698464189710236),
#  ('John Robb: "Yesterday, AT&T upgraded my cable box to a digital',
#   False,
#   0.2691938027155534),
#  ('Now we are 10', False, 0.2564238565230882),
#  ('"rssflowersalignright"I\'ve gotten to know Phil Ringalda over the',
#   False,
#   0.2532480746451924),
#  ('Rail crash bereaved sue over line safety', False, 0.2428330508588896),
#  ('Iraq Today Daily News - FREE Trial', True, 0.23548122208573938),
#  ('Information for you', True, 0.23503615452933452),
#  ('investment', True, 0.2299722968182361),
#  ('Do you dream of the latest gadgets? (ZDNET SHOPPER)',
#   False,
#   0.21160752333464397),
#  ('Keeping up with The Sims: Managing Large Scale Game Content',
#   False,
#   0.21093868623967632),
#  ('Not Many OS X Conference Blogs', False, 0.20246854647453524),
#  ('Titan to be probed. Saturn to offer post probe cigarette',
#   False,
#   0.1990382007398168),
#  ('Halley: "When is someone going to create _audio fonts_ for',
#   False,
#   0.19832430086467306),
#  ('Plans for cable', True, 0.1926233497929774),
#  ('Never pay for the goodz again (8SimUgQ)', True, 0.19044181617380795),
#  ('what is the sound of one knee jerking?', False, 0.1846894971002198),
#  ('[ILUG] STOP THE MLM INSANITY', True, 0.18045450408542474),
#  ('[ILUG] enter Chinese market', True, 0.17026213436967874),
#  ('Support for Iraq action at new low of 32%', False, 0.1515607498829589),
#  ('EFFector 15.28: Motions Filed in Morpheus Peer-to-Peer Case,',
#   False,
#   0.1499744501493966),
#  ('Cloud of anti-atoms created', False, 0.14446865890275612),
#  ('Digital service launches with 30 free channels',
#   False,
#   0.13854925319865982),
#  ('Email Marketing', True, 0.13778454477636207),
#  ('testing for taint.org, part 2', False, 0.13490010280369155),
#  ('taint.org', True, 0.12828400172246854),
#  ('Re: How unlucky can you get?', False, 0.12802736174986135),
#  ('Re: How unlucky can you get?', False, 0.12802736174986135),
#  ('Re: How unlucky can you get?', False, 0.12802736174986135),
#  ('Kanu at the double', False, 0.12745825341634606),
#  ('At last, I have an excuse', False, 0.12509856539906478),
#  ('At last, I have an excuse', False, 0.12509856539906478),
#  ('Another low probability event', False, 0.12472672113623906),
#  ('Facts about sex.', False, 0.12248633780354944),
#  ("I'm on TV tonight", False, 0.12019352550790167),
#  ('12 Reasons to Pre-Order my Novel', False, 0.11625468510182425),
#  ('Balloon flight challenges deflate', False, 0.11283697952046273),
#  ('Drug halves genital herpes transmission', False, 0.1128369795204606),
#  ('Cypriot leaders in last-ditch attempt at unification',
#   False,
#   0.10457304804236135),
#  ('Britain puts records execs in charge of copyright enforcement',
#   False,
#   0.10179349844475118),
#  ("[IIU] Eircom aDSL Nat'ing", False, 0.10045872279370437),
#  ('[ILUG] BUSINESS', True, 0.09070082355185691),
#  ("[IRR] Klez: The Virus That  Won't Die", False, 0.09050928153773709),
#  ('=?GBK?B?U3VuZnJvbSBsaWdodGluZyDE+rXEwvrS4srHztLDx9e3x/O1xMS/seo=?=',
#   True,
#   0.09049676350098527),
#  ('Friend,Instantly Copy ANY DVD or Playstation Game with this software......',
#   True,
#   0.09046676443934988),
#  ('California challenges US stem cell rules', False, 0.08868249014119677),
#  ('Gold Lake Mountain Resort looks pretty gooood. Man there are a',
#   False,
#   0.08812584285534374),
#  ('For you, and you, and Timmy', False, 0.08589701217840476),
#  ('Big Five record companies guilty of price fixing',
#   False,
#   0.08478128627557446),
#  ("Iraq invasion a 'hair-trigger' away", False, 0.08453622354769577),
#  ("Need a PDA that's more than a phonebook? (ZDNET SHOPPER)",
#   False,
#   0.08402704681442329),
#  ("Save an extra $50 of Compaq's powerful iPaq H3835! (CNET SHOPPER)",
#   False,
#   0.08376335914690064),
#  ('KVim 6.1.141', False, 0.08318382873797663),
#  ('enter Chinese market', True, 0.0811728247729152),
#  ('Act Now - Reach Hundreds of Prospects', True, 0.08065736758474297),
#  ('Roman chariots responsible for Space Shuttle design constraints',
#   False,
#   0.07984628408107798),
#  ('Sam Ruby: "Yup, I\'m a sick puppy." _Me too!_', False, 0.06738721471711659),
#  ('Early Start and Peter Gabriel', False, 0.06716612359767826),
#  ('GET IN AT THE TOP!', True, 0.06657931572983229),
#  ('FYI - gone this weekend', False, 0.06644017246213887),
#  ('Teach a man to fish', False, 0.0657135976011654),
#  ("Eagle: Lieutenant governor's race competitive, unique",
#   False,
#   0.06557669765080289),
#  ('[ILUG] VPN implementation', False, 0.06351622296916509),
#  ('[ILUG] PPPD disconnects on me!', False, 0.06299992271727996),
#  ('NY Times piece on reporters with weblogs.', False, 0.06298741561593212),
#  ('Man kills self with home booby-traps', False, 0.061581309866795504),
#  ('The Semantic Web makes me sick', False, 0.06038689165972063),
#  ('FW: Bush blew take two', False, 0.05838153621486036),
#  ('Hurricane Lili closes shuttle Mission Control',
#   False,
#   0.057097146717786866),
#  ("Rats' intestines and pigs' teeth", False, 0.05472773622249766),
#  ('Commissions Too High to Publish', True, 0.05441777413725061),
#  ("'Stay on to 70' call grows", False, 0.052614152265979104),
#  ('never a cent', False, 0.05181899321418291),
#  ('Wed. OSXCon Keynote -- Jordan Hubbard', False, 0.05102134795948909),
#  ('Medieval powers in City trial of strength', False, 0.05048457099008099),
#  ('Harvest Moon', False, 0.05006091792961714),
#  ('Geneticists and a tiny worm win Nobel prize', False, 0.049033056910972685),
#  ('Save 84% on CE Credits', True, 0.04753933394497848),
#  ('Malcolm in the Middle Sweepstakes Prize Notification',
#   False,
#   0.04729182884884596),
#  ('Jakob Nielsen on Offshore Usability: "To save costs, some',
#   False,
#   0.047186175377748836),
#  ("World's funniest joke revealed", False, 0.045311162576130354),
#  ('Re: the underground software vulnerability marketplace and its',
#   False,
#   0.045024038717264764),
#  ('Ministers issue gag orders for MI5 trial', False, 0.044055193940794886),
#  ('Scientists prove that shoe size and penis size are not linked.',
#   False,
#   0.04272015991302163),
#  ('CIGARETTES WHOLESALE!       HYWWZZLZD', True, 0.04065217105914706),
#  ('[ILUG] BANK ERROR IN YOUR FAVOR', True, 0.03899796400668894),
#  ('Pluck and Luck', False, 0.038365174305876264),
#  ('Hype is all for tired old Panorama', False, 0.03800679386619968),
#  ("'Nasty party' warning to Tories", False, 0.0372130166459148),
#  ('Speaking in Texas this Friday', False, 0.03574497753989892),
#  ("Food 'cancer chemical' reaction identified", False, 0.03504192231688761),
#  ('Comics Journal interviews Ted Rall', False, 0.03504192231685602),
#  ('[SQL] Database joins', False, 0.03504192231680748),
#  ('Goats with enormous testicles, and a life-sized cow sculpted from',
#   False,
#   0.03262116726959773),
#  ('Giant otter statue to be built', False, 0.030053633695710756),
#  ('Personalize your Palm OS device', False, 0.0285912113442599),
#  ('blogged item', False, 0.028371628118287185),
#  ('Shader Integration: Merging Shading Technologies on the Nintendo',
#   False,
#   0.02636166007531375),
#  ('Curried radiation burns', False, 0.02527063472656756),
#  ('New Solar System body revealed', False, 0.02513595429102711),
#  ('Horror writers against illiteracy', False, 0.024782279566254305),
#  ('DivX News: DivX Affiliate Program, Nobody in DivX, and New Player',
#   False,
#   0.024348165038348187),
#  ('Brown budget plans in disarray', False, 0.02168597340308442),
#  ('How I made Edwina tell all', False, 0.020077459790212047),
#  ("Profiteers resell Africa's Aids drugs", False, 0.01964361080780914),
#  ('Liddle quits Today with new BBC deal', False, 0.018321037998049468),
#  ("'Seminal' eczema study reveals skin's broken defences",
#   False,
#   0.017479420195513986),
#  ('CIA in blow to Bush attack plans', False, 0.01742951242550236),
#  ('BSkyB recruits heavyweight non-execs', False, 0.017209842263060687),
#  ("Warplane system 'could stop mid-air explosions'",
#   False,
#   0.016776528536980785),
#  ('Re: Documentum Acquires E-Room, Melding Content, Collaboration',
#   False,
#   0.016662231922149665),
#  ('Dan Gillmor responds to Jack Valenti', False, 0.016031088936463975),
#  ('Enron finance chief is handcuffed', False, 0.015972283894569388),
#  ('News.Com: "Amazon.com is hoping to use more than the honor system',
#   False,
#   0.01594682594471033),
#  ('10Mb/s through skin', False, 0.015856249493115225),
#  ('New, easy to use web conferencing software', True, 0.015652123937706357),
#  ('How to end the war....', False, 0.015358809749280828),
#  ('Deep-fried Twinkies take America by goo', False, 0.015343500503082903),
#  ('Re: How about subsidizing SSL access to Google?',
#   False,
#   0.015200160016284289),
#  ('da bomb', False, 0.013885074608544103),
#  ('Priceless', False, 0.013885074608533499),
#  ('Colonial Script ...', False, 0.013885074608532234),
#  ('Promises.', False, 0.013885074608524403),
#  ('Mayan texts reveal superpower wars', False, 0.013885074608518006),
#  ('Googlecooking', False, 0.013885074608514479),
#  ('DNA match brings breakthrough', False, 0.013885074608504532),
#  ('Fuzzy Math', False, 0.013885074608504097),
#  ('Nobel prize for British and US scientists', False, 0.013668470140771419),
#  ('Nobel prize for British and US scientists', False, 0.013668470140771419),
#  ('On The Way to Telluride, On My Way Back to the World',
#   False,
#   0.013203785605082854),
#  ('OSXCon Wed. -- James Gosling', False, 0.012347327238177613),
#  ('Creative political speech', False, 0.0123473272381615),
#  ('Bush blew take two', False, 0.012244283225250448),
#  ('[ILUG] Damian Conway in Belfast...', False, 0.01178064557836312),
#  ('Cat shot through eye with horse dart tranquilizer roams',
#   False,
#   0.011749494680902736),
#  ('catalogs.google.com - in time for xmas?', False, 0.011547976720748516),
#  ('Human-chimp DNA difference trebled', False, 0.011401930525124667),
#  ('CNET NEWS.CONTEXT: Hollywood & Silicon Valley: A way out?',
#   False,
#   0.01132025803083229),
#  ('the captain has turned off the "no hittin\' it" sign',
#   False,
#   0.010976670738399539),
#  ("Great deals on the Summer's hottest MP3 players (CNET SHOPPER)",
#   False,
#   0.010598319654447472),
#  ('Indie artist hits top-ten by engaging audience',
#   False,
#   0.010398633988431326),
#  ('http://www.efi.ie/', True, 0.010398633988423065),
#  ('UFOs in the Sky!', False, 0.01011766433267532),
#  ('Working My_Mark2CurSeen', False, 0.010013380447562078),
#  ('Liberation: Les jouebs, stars editoriales du Web.',
#   False,
#   0.00997464901620775),
#  ('Adams linked to IRA death squad', False, 0.00967589213750968),
#  ("Earth's magnetic field 'boosts gravity'", False, 0.00956969011353936),
#  ('Doom 3', False, 0.009214769845818526),
#  ('Pensioners and housebuyers suffer', False, 0.009191574533132641),
#  ('"requires:" and relational operators', False, 0.009191574533132641),
#  ("[ILUG] The Age Old 'Which Mailer' Question", False, 0.009120168903015468),
#  ('Your Daily Dilbert 07/19/2002', False, 0.008956825905207794),
#  ('Weird museums of NYC', False, 0.00893407391381845),
#  ('NEWS.COM INVESTOR: Battered stocks regain ground',
#   False,
#   0.008932200588692313),
#  ('Tired of paying big bucks for cable', True, 0.008874911398928145),
#  ('The Disappearing Alliance', False, 0.008738454770794624),
#  ('P2P slogans for EFF', False, 0.00866857347001318),
#  ('[Ximian Updates] Hyperlink handling in Gaim allows arbitrary code to be executed',
#   False,
#   0.008533935966302258),
#  ('OSXCon Thoughts for Tuesday', False, 0.008319398458165648),
#  ('How the other half gives', False, 0.00828146446656165),
#  ('Duct-tapers -- suspension and bondage fetish goes mainstream',
#   False,
#   0.00816931778946579),
#  ('Monster molecule techniques win Chemistry Nobel',
#   False,
#   0.007884916675284313),
#  ('Advanced CSS lists', False, 0.007884916675281088),
#  ('Madonna is actually quite shy', False, 0.007844560331523765),
#  ('This week: Browse or bust', False, 0.0077476389108747995),
#  ('Live forever or die trying', False, 0.007484464845928933),
#  ('Missing the Point', False, 0.007038552678263887),
#  ("Re: Hi! I'm new here.", False, 0.006973135257991847),
#  ('Relationship', True, 0.0067440144344086675),
#  ('Smitten', False, 0.0067440144344086675),
#  ('Enlightenment', False, 0.0067440144344086675),
#  ('Artist Gallery: Troy Paradise', False, 0.0067440144344086675),
#  ('Dooce', False, 0.0067440144344086675),
#  ('Cellular doom', False, 0.0067440144344086675),
#  ('Thunder Stealing', False, 0.0067440144344086675),
#  ('Oh my...', False, 0.006688913617037711),
#  ('Photoshop the worlds ugliest truck', False, 0.0066274351934778935),
#  ('Quantum cryptography takes to the skies', False, 0.006551816923647053),
#  ("Doesn't smell like team spirit", False, 0.006283903299771399),
#  ('Looking for property in SPAIN?', True, 0.006263137031996063),
#  ('Re: [ILUG] mini-itx', False, 0.006237431770618733),
#  ('[ILUG] semaphores on linux RH7.3', False, 0.0062003038905585955),
#  ('Personal laser picks for students, SOHO users, and more! (ZDNET SHOPPER)',
#   False,
#   0.0061747754675564315),
#  ('MS/Apple: Can this marriage be saved? (I doubt it) [ANCHORDESK]',
#   False,
#   0.006023113825029081),
#  ('Gearheads and bunnyhuggers in the OED', False, 0.005852044469674242),
#  ('Re: Ringing bell on other computer', False, 0.005707286762473835),
#  ('Sun donates elliptic curve code to OpenSSL? (fwd)',
#   False,
#   0.005561210388396683),
#  ('DivX News: Battle of the Planets in DivX, Warcraft III, and the',
#   False,
#   0.005519534227299335),
#  ('A Windsor in the soup', False, 0.005511284344670028),
#  ('A Line in the Sand', False, 0.005511284344670028),
#  ('Sourceforge sells out', False, 0.0054623161257689595),
#  ('Sourceforge sells out', False, 0.0054623161257689595),
#  ('Archaeological finds show that the Incas rode dinosaurs, science',
#   False,
#   0.005346200743025052),
#  ('flavor cystals', False, 0.00532396282739125),
#  ('This week: Rhapsody rules', False, 0.005148239021588693),
#  ('Labels shoot selves in foot by focusing on stopping P2P',
#   False,
#   0.005111015832054281),
#  ('Condemned man picks a black olive for his last meal. Green olives',
#   False,
#   0.00509184393576365),
#  ('Holidays for freshrpms.net :-)', False, 0.0048961249284725245),
#  ('Feedback from my posting about FogBUGZ Setup fell into four',
#   False,
#   0.004823582198979331),
#  ('More fun with the PTC', False, 0.004787733455135116),
#  ('US blueprint for smallpox mass-vaccination', False, 0.004781275459683928),
#  ("You're signed up for the Reich Report!", False, 0.0047800335183372684),
#  ('Vintage Music Archive', False, 0.004743534721120607),
#  ("Iraq invasion could 'worsen terrorist threat'",
#   False,
#   0.004743534721120306),
#  ('New Strongbad E-Mail', False, 0.004454882540226361),
#  ('ATT Wireless Location tracking', False, 0.004431099401857574),
#  ('ATT Wireless Location tracking', False, 0.004431099401857574),
#  ('Radio gives mighty roar to quiet cars', False, 0.0043705669113043594),
#  ('Man leads machine in chess duel', False, 0.00432040119359901),
#  ('Re: [ILUG] eircoms adsl modems', False, 0.004313500975892442),
#  ('Re: [ILUG] Interesting article on free software licences',
#   False,
#   0.004287290851107775),
#  ("IBM's thin ThinkPads fit to a T", False, 0.004236672989124355),
#  ('Why marching is crucial', False, 0.003950912991020289),
#  ('UAE/Ami*/Linux Laptop:  Important details.', False, 0.003814920362652802),
#  ("Re: [s-t] Scoot boss's wife orders hit.", False, 0.0037154620889960654),
#  ('Terry Pratchett - AuthorTracker News from HarperCollins',
#   False,
#   0.0036744495554193197),
#  ('Re[2]: So I missed this one...', False, 0.003582814230558885),
#  ('Your Daily Dilbert 07/11/2002', False, 0.0035200618968326824),
#  ('Lest anyone doubt that Brent has a good heart. "I laughed,',
#   False,
#   0.0035171884836966544),
#  ('[IMG: http://radio.weblogs.com/0001015/images/2002/09/25/uncSamMedium.gif',
#   False,
#   0.0035030776438179077),
#  ('[zzzzteana] Fake bank website cons victims', False, 0.0034188533613423214),
#  ('A revolution in the PC world has arrived.          RSIRTR',
#   True,
#   0.003417485039525446),
#  ('Apple Switch parodies', False, 0.003413008883494017),
#  ('NEWS.COM INVESTOR: Techs fall with consumer sentiment',
#   False,
#   0.0033846007813604097),
#  ('In praise of evolvable formats', False, 0.003275043275187904),
#  ('Sun', False, 0.003230695193292012),
#  ('ru stupid', False, 0.0032306951932919666),
#  ('Rambus, Man', False, 0.0032144391445738598),
#  ('When to Sell Online Seminar, Lesson 2: Companies Gone Wrong',
#   False,
#   0.0030542624578803884),
#  ('RE: <nettime> The War Prayer', False, 0.0028131510947521283),
#  ('Re: [zzzzteana] FWD [fort] Evidence Britons Were In The US In The6th Century',
#   False,
#   0.0027931351139429974),
#  ('Toward Mac OS XX', False, 0.0027716327063937174),
#  ('Palm-sized translators going to Iraq', False, 0.00271010543965913),
#  ('Freedom deal for Real IRA man', False, 0.002684003346941064),
#  ('Cast not the first stone', False, 0.002636767202210089),
#  ('Re: SunMSapple meta4 of the day', False, 0.0025332669008649284),
#  ('MiniNTK 2002-08-16', False, 0.0024384189104763435),
#  ('.Message report from your contact page....//ytu855 rkq',
#   True,
#   0.002409409712441657),
#  ('[zzzzteana] Re: Cincinnati Group Wants To Stamp Out Hotel Sex Movies',
#   False,
#   0.002286401582011311),
#  ('Re: A couple of nits...', False, 0.0022203583605487293),
#  ('US use of lie detector tests criticised', False, 0.002167527259462769),
#  ('NEW TECHNOLOGY - DIGITAL VIDEO RECORDER (Smart IP Technology)',
#   True,
#   0.002115208463209145),
#  ('find the bug', False, 0.0020718213112656844),
#  ('Drivezilla -- 200GB Drives from Western Digital',
#   False,
#   0.002010901945931429),
#  ('Dotcom Scoop: "CNET\'s Download.com is set to introduce a new',
#   False,
#   0.0020084514917504404),
#  ('New light on a lost world of shattered icons',
#   False,
#   0.0019640230640700076),
#  ('GDC 2002: Game Scripting in Python', False, 0.0019474651230286038),
#  ('GDC 2002: Game Scripting in Python', False, 0.0019474651230286038),
#  ('Neutrino and X-ray physicists win Nobel Prize',
#   False,
#   0.0018917159906907805),
#  ('Invite: Content Management Summit, Oct. 10th New York City',
#   True,
#   0.001854613670263826),
#  ('Astrology.com: daily horoscope', False, 0.0018545726992268135),
#  ('Was child beating mom an enraged con artist?',
#   False,
#   0.0018261276320254687),
#  ('Oracle Technology Network TechBlast - July 2002',
#   False,
#   0.0017947952856901392),
#  ("Why we're changing our publishing schedule [ANCHORDESK]",
#   False,
#   0.001735445023320281),
#  ('Oh ma gawd - funny site of the day...', False, 0.001726734791825672),
#  ('Debian-style task-packages for RH8.0 available',
#   False,
#   0.0016270014142624443),
#  ('[Spambayes] [ANN] Trained classifier available',
#   False,
#   0.0016259667523391781),
#  ('storage bits', False, 0.0015448059738563257),
#  ('creating rpms with subdirs (install command)',
#   False,
#   0.0014796625604563591),
#  ('[zzzzteana] Frog Fall at Cheapside', False, 0.0013996660660758448),
#  ("Gillmor: Apple's fair-use friendly OS?", False, 0.0013949635769387463),
#  ('September Core Java Technologies Newsletter', False, 0.0013812894690617733),
#  ('Xine dependencies', False, 0.001380161405512241),
#  ('Entrepreneurs', False, 0.001268751336999796),
#  ('Reg Headlines Friday July 19', False, 0.0012041890651412726),
#  ('Oracle of Google', False, 0.0011685178263301991),
#  ('Oracle of Google', False, 0.0011685178263301991),
#  ('Oracle of Google', False, 0.0011685178263301991),
#  ('Product Review: Virtools Dev 2.0', False, 0.001138968312774001),
#  ('[ILUG] Re: serial console...not quite working',
#   False,
#   0.001133791284228039),
#  ("When search results don't count (Tech Update)",
#   False,
#   0.0010957301459489823),
#  ('Apt 0.3 and 0.5', False, 0.001065150644346027),
#  ('NEWS.COM INVESTOR: Techs rise, but Dow falls on day of Bush speech',
#   False,
#   0.001059755690222235),
#  ('Re: [zzzzteana] Nothing like mama used to make',
#   False,
#   0.0010570298179292407),
#  ('Re: Should mplayer be build with Win32 codecs?',
#   False,
#   0.0010486603726916342),
#  ('Re: Should mplayer be build with Win32 codecs?',
#   False,
#   0.0010486603726916342),
#  ('Re: Should mplayer be build with Win32 codecs?',
#   False,
#   0.0010486603726916342),
#  ('[SAdev] [Bug 839] mailbox corruption not fixed with procmail 3.22',
#   False,
#   0.0010283651072618668),
#  ('[zzzzteana] Six arrested for attacking Palio jockey who defected',
#   False,
#   0.0010256473270321025),
#  ('Blue people of the world unite!', False, 0.0010204508418661564),
#  ('The case for spam', False, 0.0009808460388503859),
#  ('The case for spam', False, 0.0009808460388503859),
#  ('RE: MIT OpenCourseWare', False, 0.0009708788204721087),
#  ('Re: Computational Recreations', False, 0.0009708788204707164),
#  ('Re: Computational Recreations', False, 0.0009708788204707164),
#  ('Re: [SAtalk] where can I find the Habeas patent (application)?',
#   False,
#   0.0009432316886381887),
#  ('Colophon 2', False, 0.0009419324345219646),
#  ('Re: Working My_Mark2CurSeen', False, 0.0009351555095114009),
#  ('Re: Working My_Mark2CurSeen', False, 0.0009351555095114009),
#  ('[Razor-users] FW: [EVENT NOTIFICATION] UUnet North American',
#   False,
#   0.0009023110700038673),
#  ("If you're going to turn on an electric pump to remove water from",
#   False,
#   0.0008978625660901052),
#  ('[zzzzteana] The new Steve Earle', False, 0.0008970780846869162),
#  ('Re: [ILUG] adsl router modem combo', False, 0.0008786257831942045),
#  ('Re: "requires:" and relational operators', False, 0.00085776102524152),
#  ('Re: xmms and .mp3 files.', False, 0.0008409401440481819),
#  ('Re: The Disappearing Alliance', False, 0.0008151377334776433),
#  ('Re: Nessus?', False, 0.0007808223469544359),
#  ('Reg Headlines Friday July 12', False, 0.0007731245465822389),
#  ("The Ozone Hole is getting smaller... But Leroy's Getting LARRRRRGER",
#   False,
#   0.0007223564618490067),
#  ('Re: The absurdities of life.', False, 0.0006742262002775154),
#  ('Re: The absurdities of life.', False, 0.0006742262002775154),
#  ("Perl.  It's just a language.", False, 0.000643445819599298),
#  ('Re: girls', True, 0.0006279474021156128),
#  ('Re: Snow', False, 0.0006279474021156128),
#  ('Re: Oh my...', False, 0.0006227855331119504),
#  ('Re: Oh my...', False, 0.0006227855331119504),
#  ('Good Earnings Report', False, 0.000602992747437885),
#  ('Re: Content management for MP3s', False, 0.0005582248101112768),
#  ('Re: K3B', False, 0.0005575731841865291),
#  ('Re: K3B', False, 0.0005575731841865291),
#  ('Re: K3B', False, 0.0005575731841865291),
#  ('RE: Prob. w/ install/uninstall', False, 0.0005469729430506737),
#  ('apt-get http fails', False, 0.000521980505055496),
#  ('CNET NEWS.COM: Copies, Webcasts tangled in draft bill',
#   False,
#   0.000521170383067471),
#  ('Yoga & Painfree Bliss', False, 0.0005109776453566611),
#  ('Re: flavor cystals', False, 0.0004950819148663286),
#  ('Re: patent on TMDA-like system', False, 0.00048309766777474944),
#  ('Re: From', False, 0.00048035381051984567),
#  ('Re: From', False, 0.00048035381051984567),
#  ('Re: From', False, 0.00048035381051984567),
#  ('Re: The risks of client systems writing to server registry',
#   False,
#   0.0004798441188574978),
#  ('[Spambayes] all but one testing', False, 0.00045389669754888423),
#  ('[Spambayes] All but one testing', False, 0.00045389669754888423),
#  ('RE: Gasp!', False, 0.00043350276076003016),
#  ('Re: lifegem', False, 0.00043350276075950525),
#  ('Re: lifegem', False, 0.00043350276075950525),
#  ('Re: results for giant mass-check (phew)', False, 0.000426616423260082),
#  ('Re: mplayer not working for me', False, 0.00042161681675250383),
#  ("Clinton: Blair's the man to trust", False, 0.0004174824567046943),
#  ('Re: [zzzzteana] The Cafe Forteana is back online!!!',
#   False,
#   0.00040865339688057114),
#  ('Re: [zzzzteana] The Cafe Forteana is back online!!!',
#   False,
#   0.00040865339688057114),
#  ('[Lockergnome Penguin Shell]  Karaoke Kernel', False, 0.0004037187151889354),
#  ('Re: [ILUG] Re: Sun Solaris', False, 0.00039308281361745645),
#  ('[zzzzteana] Lioness adopts fifth antelope', False, 0.00038427483813365925),
#  ('[zzzzteana] Moscow bomber', False, 0.00038427483813365925),
#  ('[Spambayes] All Cap or Cap Word Subjects', False, 0.0003763976022117171),
#  ('Re: [ILUG] Serial number in hosts file', False, 0.0003747637267079776),
#  ('[zzzzteana] A Billy for the septics', False, 0.000373343180486382),
#  ('[Lockergnome Webmaster Weekly]  Compatible Whistles',
#   False,
#   0.00034989381992883044),
#  ('[Lockergnome Webmaster Weekly]  Educational Capabilities',
#   False,
#   0.00034989381992883044),
#  ('[zzzzteana] Uncle Mark seeks parole', False, 0.00032987172986494244),
#  ('Secure Sofware Key', False, 0.00031799587974461684),
#  ('Re: Please help a newbie compile mplayer :-)',
#   False,
#   0.0003079511159814516),
#  ('Re: Rambus, Man', False, 0.000298340800242787),
#  ('[Spambayes] XTreme Training', False, 0.00029817096068005227),
#  ('[Spambayes] XTreme Training', False, 0.00029817096068005227),
#  ('[zzzzteana] Punch bags filled with incontinence pads',
#   False,
#   0.00029387946669422014),
#  ('Re: Polit-spam', False, 0.00028100215124244254),
#  ('[Lockergnome Tech Specialist]  Friend Fry', False, 0.00027455649680784873),
#  ('RE: [zzzzteana] Moon over ocean', False, 0.0002605033871087294),
#  ('Re: ActiveBuddy', False, 0.00025975240805368863),
#  ('Re: ActiveBuddy', False, 0.00025975240805368863),
#  ('Re: ActiveBuddy', False, 0.00025975240805368863),
#  ('Re: ActiveBuddy', False, 0.00025975240805368863),
#  ('[Spambayes] testing results', False, 0.00024365208980881107),
#  ('[Spambayes] testing results', False, 0.00024365208980881107),
#  ('earthviewer apps Re: whoa', False, 0.0002397970088385638),
#  ('Is rap music art? Rap song about farting answers that question',
#   False,
#   0.00023235025714611943),
#  ('Re: Apple Sauced...again', False, 0.0002320242142665742),
#  ('Re: Apple Sauced...again', False, 0.0002320242142665742),
#  ('Re: DataPower announces XML-in-silicon', False, 0.00022939435568368496),
#  ('Re: DataPower announces XML-in-silicon', False, 0.00022939435568368496),
#  ('Reg Headlines Wednesday July 17', False, 0.00022229165395965016),
#  ('RE: [ILUG] [OT] Dell machine giving me hassle.',
#   False,
#   0.0002195802979580016),
#  ('[zzzzteana] Nobel astrophysicists', False, 0.00021693469491999558),
#  ('Re: Mplayer', False, 0.00020487132550854178),
#  ('Re: Mplayer', False, 0.00020487132550854178),
#  ('Re: whoa', False, 0.00020487132550835041),
#  ('Re: [zzzzteana] Fortean Times Online', False, 0.00020435429461520679),
#  ('Re: [VoID] a new low on the personals tip...',
#   False,
#   0.00020163985425720904),
#  ('Re: [VoID] a new low on the personals tip...',
#   False,
#   0.00020163985425720904),
#  ('Re: [VoID] a new low on the personals tip...',
#   False,
#   0.00020163985425720904),
#  ('Re: [VoID] a new low on the personals tip...',
#   False,
#   0.00020163985425720904),
#  ('Re: sylpheed-claws', False, 0.00020014183592116934),
#  ('Slaughter in the Name of God', False, 0.0001942578782472832),
#  ('[Lockergnome Penguin Shell]  Good Hearts', False, 0.0001937353443260016),
#  ('Mac OS X browsers', False, 0.0001880619251737413),
#  ('Shelley Powers raises some interesting questions re whether RDF',
#   False,
#   0.00018051412634084363),
#  ('Re: Bug report: msg n+1 marked read', False, 0.00016979421452147737),
#  ('Re: apt and a hybrid system', False, 0.00016797526259619517),
#  ('Re: apt and a hybrid system', False, 0.00016797526259619517),
#  ('Re: [SAtalk] getting single-user spam assassin to work in FreeBSD',
#   False,
#   0.00015936267856301857),
#  ('Re: Wifi query', False, 0.00015812854561525776),
#  ('CNET DIGITAL DISPATCH: Mac zealots unite', False, 0.00015779193975958393),
#  ('Re: [SAdev] Re: [SACVS] CVS: spamassassin/rules 60_whitelist.cf,1.29,1.30',
#   False,
#   0.00015727997520892373),
#  ('Re: [SAtalk] PerMsgStatus.pm error?', False, 0.00015270826295123667),
#  ('Still hunting for the perfect RAM upgrade? (CNET SHOPPER)',
#   False,
#   0.0001515597538962616),
#  ('Re: Encryption approach to secure web applications',
#   False,
#   0.00012917095544635564),
#  ('[SAdev] [Bug 1053] IMG tag based rules', False, 0.00012594738548116558),
#  ('RE: liberal defnitions', False, 0.00012401167540216339),
#  ('CNET NEWS.COM: The tech side of homeland defense',
#   False,
#   0.00012400652266424548),
#  ('Re: Entrepreneurs', False, 0.0001175480931678529),
#  ('Re: Entrepreneurs', False, 0.0001175480931678529),
#  ('Re: Entrepreneurs', False, 0.0001175480931678529),
#  ('Re: [zzzzteana] The Coming Firestorm', False, 0.00011175828728953466),
#  ('Re: Insert signature', False, 0.00010742419011089356),
#  ('Re: Insert signature', False, 0.00010742419011089356),
#  ('[Spambayes] hammie.py vs. GBayes.py', False, 0.0001061744940991451),
#  ('Re: Sorting', False, 0.00010473490715246989),
#  ('Re: Sorting', False, 0.00010473490715246989),
#  ('Re: Sorting', False, 0.00010473490715246989),
#  ('Re: Sorting', False, 0.00010473490715246989),
#  ('Re: Sorting', False, 0.00010473490715246989),
#  ('Re: Avast there matey', False, 9.761037565854179e-05),
#  ('Re: bad DCC traffic from e-corp.net', False, 9.752785652208423e-05),
#  ('[Lockergnome Digital Media]  Humblest Alarm', False, 9.58489009534785e-05),
#  ('[Lockergnome Windows Daily]  Fraud Wipes', False, 9.276226781613708e-05),
#  ('Re: The case for spam', False, 9.085029410335626e-05),
#  ('Re: The case for spam', False, 9.085029410335626e-05),
#  ('Re: The case for spam', False, 9.085029410335626e-05),
#  ('Re: boycotting yahoo', False, 8.844839644614188e-05),
#  ('Re: boycotting yahoo', False, 8.844839644614188e-05),
#  ('[SAtalk] "Broken Pipe" on initial test', False, 8.646484503407442e-05),
#  ('Re: New testing packages', False, 8.346458538565497e-05),
#  ('Re: Re[4]: A moment of silence for the First Amendment (fwd)',
#   False,
#   7.691175277536392e-05),
#  ('RE: Re[4]: A moment of silence for the First Amendment (fwd)',
#   False,
#   7.691175277536392e-05),
#  ('Re: sprint delivers the next big thing??', False, 7.59227393000085e-05),
#  ('RE: sprint delivers the next big thing??', False, 7.59227393000085e-05),
#  ('[Lockergnome Windows Daily]  Deeper Uplink', False, 7.459055599232097e-05),
#  ('[Lockergnome Windows Daily]  Brilliant Mistakes',
#   False,
#   7.459055599232097e-05),
#  ('[Lockergnome Windows Daily]  Dignity Shakedown',
#   False,
#   7.459055599232097e-05),
#  ('[zzzzteana] Re: Australian Catholic Kiddie Perv Steps Aside',
#   False,
#   7.37698639667516e-05),
#  ('Re[2]: Oh my...', False, 6.957531311530687e-05),
#  ('RE: [ILUG] Redhat 8.0', False, 6.752172592329896e-05),
#  ('[Spambayes] Ditching WordInfo', False, 6.638153254565392e-05),
#  ('[Spambayes] Ditching WordInfo', False, 6.638153254565392e-05),
#  ('Re: New gkrellm 2.0.0, gtk2 version', False, 6.415315430402662e-05),
#  ('Re: [SAdev] Re: several messages', False, 6.285314554974694e-05),
#  ('Re: CD player UI for toddlers', False, 5.845811196453828e-05),
#  ('Re: CD player UI for toddlers', False, 5.845811196453828e-05),
#  ('Re: latest php upgrade in 7.3', False, 5.792110713299708e-05),
#  ("(PGP problem) EXMH hangs during 'Query keyserver'",
#   False,
#   5.288596940977698e-05),
#  ('Re: Recommended Viewing', False, 4.9868028505223834e-05),
#  ('RE: Recommended Viewing', False, 4.9868028505223834e-05),
#  ('Re: Recommended Viewing', False, 4.9868028505223834e-05),
#  ('Re: [SAtalk] Too funny', False, 4.4918819251227526e-05),
#  ('[Spambayes] spambayes package?', False, 4.4407473195358795e-05),
#  ('[Spambayes] spambayes package?', False, 4.4407473195358795e-05),
#  ('Re: Changed location of incoming mail. exmh not working!!',
#   False,
#   4.335038781308109e-05),
#  ('[Spambayes] Current histograms', False, 4.288860176585525e-05),
#  ('[Spambayes] Current histograms', False, 4.288860176585525e-05),
#  ('[Spambayes] Current histograms', False, 4.288860176585525e-05),
#  ('Re: [SAtalk] OT: DNS MX Record Clarification Please',
#   False,
#   4.1068440133061935e-05),
#  ('Re: [SAdev] results of scorer evaluation', False, 4.0306102553555414e-05),
#  ('Re: [SAdev] results of scorer evaluation', False, 4.0306102553555414e-05),
#  ('Re: [SAtalk] Re: patent on TMDA-like system', False, 3.94485370114681e-05),
#  ('problems with apt update', False, 3.710871432762596e-05),
#  ('Re: dylsexics of the wrold, untie!', False, 3.673134130015862e-05),
#  ('Re: dylsexics of the wrold, untie!', False, 3.673134130015862e-05),
#  ('[SACVS] CVS: spamassassin procmailrc.example,1.3,1.3.2.1',
#   False,
#   3.668220395817413e-05),
#  ('Re: RedHat 8.0 and his own freetype', False, 3.619257114348543e-05),
#  ('Re: RedHat 8.0 and his own freetype', False, 3.619257114348543e-05),
#  ('Re: RedHat 8.0 and his own freetype', False, 3.619257114348543e-05),
#  ('Re: RedHat 8.0 and his own freetype', False, 3.619257114348543e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('[Spambayes] Deployment', False, 3.2937446053200655e-05),
#  ('Re: [SAtalk] telesp.net.br?', False, 3.238239946795603e-05),
#  ('[SACVS] CVS: spamassassin/t db_based_whitelist.t,1.7,1.8',
#   False,
#   3.231647968359318e-05),
#  ('Re: ARRRGHHH Had GPG working, now it doesnt.',
#   False,
#   3.2244741395780385e-05),
#  ('Re: ARRRGHHH Had GPG working, now it doesnt.',
#   False,
#   3.2244741395780385e-05),
#  ('[use Perl] Stories for 2002-10-01', False, 3.146576357515946e-05),
#  ('[Spambayes] stack.pop() ate my multipart message',
#   False,
#   3.1054243125617076e-05),
#  ('[SAtalk] Spamassassin with Pyzor', False, 3.0375305332502008e-05),
#  ('Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#   False,
#   3.0331252679306933e-05),
#  ('RE: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#   False,
#   3.0331252679306933e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: Secure Sofware Key', False, 2.9436461423092932e-05),
#  ('Re: [SAdev] phew!', False, 2.691084108560397e-05),
#  ('Re: dumb question: X client behind a firewall?',
#   False,
#   2.6256873146291506e-05),
#  ("Re: The Curse of India's Socialism", False, 2.4317927843995057e-05),
#  ('Re: [SAtalk] dependencies / pre-requisites for installation in',
#   False,
#   2.4074375070814596e-05),
#  ("Re: Help! I've lost my exmh-unseen window!", False, 2.406462126874038e-05),
#  ("Re: Help! I've lost my exmh-unseen window!", False, 2.406462126874038e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('Re: bad focus/click behaviours', False, 2.3641021326263586e-05),
#  ('EBusiness Webforms: cluetrain has left the station',
#   False,
#   2.279771831635741e-05),
#  ('[SACVS] CVS: spamassassin/lib/Mail SpamAssassin.pm,1.115.2.11,1.115.2.12',
#   False,
#   2.229888739975198e-05),
#  ('Re: [gst-devel] Red Hat 8.0', False, 2.108181883200002e-05),
#  ('Re: Apt problems', False, 2.107199393502639e-05),
#  ('[use Perl] Headlines for 2002-10-02', False, 2.085762979919748e-05),
#  ('Re: http://apt.nixia.no/', False, 2.0706309500489004e-05),
#  ('[IRR] Re: The 3rd Annual Consult Hyperion Digital Identity Forum',
#   False,
#   1.9717684550846704e-05),
#  ('Re: [SAtalk] Still confused about spamd/c', False, 1.946033513022558e-05),
#  ('Re: A moment of silence for the First Amendment (fwd)',
#   False,
#   1.8873591848670618e-05),
#  ('Re: A moment of silence for the First Amendment (fwd)',
#   False,
#   1.8873591848670618e-05),
#  ('Re: A moment of silence for the First Amendment (fwd)',
#   False,
#   1.8873591848670618e-05),
#  ('Re: Zoot apt/openssh & new DVD playing doc', False, 1.809936572110207e-05),
#  ('RE: Slaughter in the Name of God', False, 1.7980177427242475e-05),
#  ('RE: Slaughter in the Name of God', False, 1.7980177427242475e-05),
#  ('Re: Slaughter in the Name of God', False, 1.7980177427242475e-05),
#  ('Re: Slaughter in the Name of God', False, 1.7980177427242475e-05),
#  ('Re: Microsoft buys XDegress - more of a p2p/distributed data thing...',
#   False,
#   1.7109692646352253e-05),
#  ('ALSA (almost) made easy', False, 1.5863642566159536e-05),
#  ('[use Perl] Stories for 2002-08-30', False, 1.581764941179272e-05),
#  ("Re: problems with 'apt-get -f install'", False, 1.5162099335609962e-05),
#  ('Fwd: Re[2]: AA Meetings the Hottest Place to Meet Women With Big',
#   False,
#   1.3755566184072953e-05),
#  ('[SAdev] [Bug 1075] RPM build puts wrong path in the *.cf files',
#   False,
#   1.3622948346616052e-05),
#  ('RE: Our friends the Palestinians, Our servants in government.',
#   False,
#   1.3410155424646803e-05),
#  ('RE: Our friends the Palestinians, Our servants in government.',
#   False,
#   1.3410155424646803e-05),
#  ('Re: Our friends the Palestinians, Our servants in government.',
#   False,
#   1.3410155424646803e-05),
#  ('Re: Another sequences window nit', False, 1.282631914852305e-05),
#  ('[use Perl] Headlines for 2002-08-30', False, 1.280051319263118e-05),
#  ('Re: Python 2.2 site libs?', False, 1.2295195536727318e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: New Sequences Window', False, 1.202276584088564e-05),
#  ('Re: [SAdev] Have mass-check remove X-Spam-* headers?',
#   False,
#   1.1946829404540377e-05),
#  ('Re: CVS report', False, 1.1076052179351133e-05),
#  ('Re: CVS report', False, 1.1076052179351133e-05),
#  ('Re: CVS report', False, 1.1076052179351133e-05),
#  ('Re: CVS report', False, 1.1076052179351133e-05),
#  ('RE: [SAtalk] Getting yourself removed from spam lists',
#   False,
#   1.0611504253997994e-05),
#  ('Re: [SAtalk] Getting yourself removed from spam lists',
#   False,
#   1.0611504253997994e-05),
#  ('[use Perl] Stories for 2002-08-27', False, 1.0056212828942333e-05),
#  ('asynchronous I/O (was Re: Gasp!)', False, 9.877401869250666e-06),
#  ('Re: asynchronous I/O (was Re: Gasp!)', False, 9.877401869250666e-06),
#  ('[Razor-users] Performance', False, 9.398249820427629e-06),
#  ('Re: [SAdev] SpamAssassin POP3 proxy', False, 9.343270601120493e-06),
#  ('Re: traceback in new exmh', False, 8.83155710514887e-06),
#  ('Re: traceback in new exmh', False, 8.83155710514887e-06),
#  ('use of base image / delta image for automated recovery from attacks',
#   False,
#   8.633091380450567e-06),
#  ('[Razor-users] honor is not in csl', False, 7.461542190782995e-06),
#  ('Re: Electric car an Edsel...', False, 7.429768772541661e-06),
#  ('Re: Java is for kiddies', False, 6.677644076198498e-06),
#  ('RE: Java is for kiddies', False, 6.677644076198498e-06),
#  ('RE: Java is for kiddies', False, 6.677644076198498e-06),
#  ('Re: Java is for kiddies', False, 6.677644076198498e-06),
#  ('Re: Java is for kiddies', False, 6.677644076198498e-06),
#  ('Re: [SAtalk] 2.42: est release?', False, 5.649114454220847e-06),
#  ('Re: Anolther sequence related traceback', False, 5.643678188395701e-06),
#  ('Re: Anolther sequence related traceback', False, 5.643678188395701e-06),
#  ('Re: Anolther sequence related traceback', False, 5.643678188395701e-06),
#  ('Re: Anolther sequence related traceback', False, 5.643678188395701e-06),
#  ('Re: [SAtalk] test', False, 5.5213882705743555e-06),
#  ('Re: About apt, kernel updates and dist-upgrade',
#   False,
#   5.500026139425209e-06),
#  ('Re: About apt, kernel updates and dist-upgrade',
#   False,
#   5.500026139425209e-06),
#  ('Re: "Ouch. Ouch. Ouch. Ouch. Ouch...."(was Re: My brain hurts)',
#   False,
#   5.259478988204887e-06),
#  ('Re: "Ouch. Ouch. Ouch. Ouch. Ouch...."(was Re: My brain hurts)',
#   False,
#   5.259478988204887e-06),
#  ('Re: [SAtalk] Yeah right... If spamassassin was looking through th',
#   False,
#   5.155890496716218e-06),
#  ('[Razor-users] Razor with sendmail', False, 4.960449631101275e-06),
#  ('Re: RH 8 no DMA for DVD drive', False, 4.433000620209314e-06),
#  ('Re: RH 8 no DMA for DVD drive', False, 4.433000620209314e-06),
#  ('Re: RH 8 no DMA for DVD drive', False, 4.433000620209314e-06),
#  ('Re: RH 8 no DMA for DVD drive', False, 4.433000620209314e-06),
#  ('Re: RH 8 no DMA for DVD drive', False, 4.433000620209314e-06),
#  ('Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#   False,
#   4.340429857571839e-06),
#  ('Re: [SAtalk] base64 decode problem?', False, 4.176937961119489e-06),
#  ("[SAdev] [Bug 1006] Spamassassin's build process makes packaging",
#   False,
#   3.976618048357383e-06),
#  ('[Razor-users] Razor2 error: can\'t find "new"',
#   False,
#   3.5535015669043173e-06),
#  ('[Razor-users] Razor2 error: can\'t find "new"',
#   False,
#   3.5535015669043173e-06),
#  ('RE: Goodbye Global Warming', False, 3.4554258738307213e-06),
#  ('Re: Goodbye Global Warming', False, 3.4554258738307213e-06),
#  ('Re: Goodbye Global Warming', False, 3.4554258738307213e-06),
#  ('RE: Goodbye Global Warming', False, 3.4554258738307213e-06),
#  ('Re: Goodbye Global Warming', False, 3.4554258738307213e-06),
#  ('Re[2]: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#   False,
#   3.386712756481444e-06),
#  ('[use Perl] Stories for 2002-09-14', False, 3.3177321717482803e-06),
#  ('Re: [SAtalk] Re: SA In The News', False, 3.1612517504563883e-06),
#  ('[use Perl] Stories for 2002-09-20', False, 3.1393926768858394e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] test sets?', False, 2.936536777958796e-06),
#  ('[Spambayes] deleting "duplicate" spam before training?  good idea',
#   False,
#   2.807008597750309e-06),
#  ('Re: [scoop] Scoop MS Word .doc file into something that plucker or other Palm app can display?',
#   False,
#   2.7330875603448977e-06),
#  ('Re: [SAtalk] False Positive of the Week', False, 2.701612514262046e-06),
#  ('Re: All set for Red Hat Linux 8.0', False, 2.5030586540703126e-06),
#  ('Re: [SAtalk] [OT] SpamAssassin figures...', False, 2.4861137021798113e-06),
#  ('[use Perl] Stories for 2002-09-01', False, 2.4365444589175086e-06),
#  ('RE: CO2 and climate (was RE: Goodbye Global Warming)',
#   False,
#   2.327183414012419e-06),
#  ('[use Perl] Headlines for 2002-08-24', False, 2.2091346602575528e-06),
#  ('Re: EBusiness Webforms: cluetrain has left the station',
#   False,
#   2.109789543783765e-06),
#  ('Re[2]: A moment of silence for the First Amendment (fwd)',
#   False,
#   2.107357198343904e-06),
#  ('[use Perl] Stories for 2002-09-10', False, 2.075546895066351e-06),
#  ('[use Perl] Stories for 2002-09-13', False, 1.995779137431635e-06),
#  ('[use Perl] Headlines for 2002-09-18', False, 1.9749965958828796e-06),
#  ('[use Perl] Headlines for 2002-09-01', False, 1.9717809562990326e-06),
#  ('[use Perl] Headlines for 2002-09-13', False, 1.615090153971516e-06),
#  ('Comrade Communism (was Re: Crony Capitalism (was RE: sed',
#   False,
#   1.565530797072743e-06),
#  ('Re: [ILUG] windows users accessing cvs...', False, 1.543441930792616e-06),
#  ('[SAdev] [Bug 886] Add a rule to detect Content-type message/partial',
#   False,
#   1.5402453228948176e-06),
#  ('[Spambayes] Maybe change X-Spam-Disposition to something else...',
#   False,
#   1.5387897304018178e-06),
#  ('Re: Bindings problem with current CVS code', False, 1.4845996637428791e-06),
#  ('Re: ALSA (almost) made easy', False, 1.4680739600994804e-06),
#  ('Re: ALSA (almost) made easy', False, 1.4680739600994804e-06),
#  ('Re: ALSA (almost) made easy', False, 1.4680739600994804e-06),
#  ('Re: ALSA (almost) made easy', False, 1.4680739600994804e-06),
#  ('Re: ALSA (almost) made easy', False, 1.4680739600994804e-06),
#  ('[use Perl] Stories for 2002-09-23', False, 1.461190312663477e-06),
#  ('[Spambayes] deleting "duplicate" spam before training?  good idea or',
#   False,
#   1.4082254361467782e-06),
#  ('[use Perl] Headlines for 2002-09-11', False, 1.3909069740404196e-06),
#  ('[Spambayes] understanding high false negative rate',
#   False,
#   1.3743251964674237e-06),
#  ('[Spambayes] understanding high false negative rate',
#   False,
#   1.3743251964674237e-06),
#  ('[Spambayes] understanding high false negative rate',
#   False,
#   1.3743251964674237e-06),
#  ('[use Perl] Headlines for 2002-09-23', False, 1.1824724500582078e-06),
#  ('Re: Problem with an rpm...', False, 1.1247214586230272e-06),
#  ('Re: Problem with an rpm...', False, 1.1247214586230272e-06),
#  ('Re: Problem with an rpm...', False, 1.1247214586230272e-06),
#  ('RE: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('Re: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('Re: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('Re: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('Re: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('RE: [SAtalk] O.T. Habeus -- Why?', False, 9.681680118028896e-07),
#  ('Re: use of base image / delta image for automated recovery from',
#   False,
#   8.99829930135194e-07),
#  ('Re: use of base image / delta image for automated recovery from',
#   False,
#   8.99829930135194e-07),
#  ('Re: [SAtalk] Re: AWL bug in 2.42?', False, 7.514825283214104e-07),
#  ('RE: Re[2]: Java is for kiddies', False, 7.455935766146153e-07),
#  ('Re[2]: Java is for kiddies', False, 7.455935766146153e-07),
#  ('use new apt to do null to RH8 upgrade?', False, 5.656021692451985e-07),
#  ('[Razor-users] Re: Can\'t use and undefined value.." error',
#   False,
#   5.607412820890209e-07),
#  ('Re: alsa-driver.spec tweak for homemade kernels',
#   False,
#   5.513776684117036e-07),
#  ('[use Perl] Headlines for 2002-09-03', False, 5.36673654514997e-07),
#  ('Re: [Razor-users] Razor with sendmail', False, 4.5905187604847797e-07),
#  ('RE: [Razor-users] Razor with sendmail', False, 4.5905187604847797e-07),
#  ('The GOv gets tough on Net Users.....er Pirates..',
#   False,
#   4.058415628424808e-07),
#  ('Re: Linking message [was: Re: Patch to complete a change...]',
#   False,
#   2.9764017869001895e-07),
#  ('Re: Gabber packages for 8.0 (was: All set for Red Hat Linux 8.0)',
#   False,
#   2.169666754243399e-07),
#  ('Re: [SAtalk] SpamAssassin v2.40 released (finally)!',
#   False,
#   1.2726094409580808e-07),
#  ('Re: [SAdev] 2.40 RELEASE PROCESS: mass-check status, folks?',
#   False,
#   9.012753722038969e-08),
#  ('Re: [SAdev] SpamAssassin v2.40 released (finally)!',
#   False,
#   7.521193970037564e-08),
#  ('Re: [SAdev] SpamAssassin v2.40 released (finally)!',
#   False,
#   7.521193970037564e-08),
#  ('Re: use new apt to do null to RH8 upgrade?', False, 5.234196911843787e-08),
#  ('Re: use new apt to do null to RH8 upgrade?', False, 5.234196911843787e-08),
#  ('Re: [SAtalk] Re: [SAdev] File::Spec and v2.41',
#   False,
#   4.487194916306488e-08),
#  ('Re: The GOv gets tough on Net Users.....er Pirates..',
#   False,
#   3.755739391522997e-08),
#  ('Re: The GOv gets tough on Net Users.....er Pirates..',
#   False,
#   3.755739391522997e-08),
#  ("Re: Hanson's Sept 11 message in the National Review",
#   False,
#   2.8589841293751015e-08),
#  ("RE: Hanson's Sept 11 message in the National Review",
#   False,
#   2.8589841293751015e-08),
#  ('Re: sed /s/United States/Roman Empire/g', False, 9.008189219287444e-09),
#  ('RE: sed /s/United States/Roman Empire/g', False, 9.008189219287444e-09),
#  ('Re: sed /s/United States/Roman Empire/g', False, 9.008189219287444e-09),
#  ('Re: sed /s/United States/Roman Empire/g', False, 9.008189219287444e-09),
#  ('[Razor-users] Problem with Razor 2.14 and Spamassassin 2.41',
#   False,
#   3.851792479158925e-09),
#  ('Re[3]: Selling Wedded Bliss (was Re: Ouch...)',
#   False,
#   2.6854106717142462e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: Selling Wedded Bliss (was Re: Ouch...)', False, 1.960482826979075e-09),
#  ('Re: [SAtalk] checking out Razor2 (and SA 2.41) install - Net::DNS:Resolver problem?',
#   False,
#   1.0287954956778856e-09),
#  ('Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41',
#   False,
#   3.5645248760271325e-10),
#  ('Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#   False,
#   2.1889677222997326e-10),
#  ('RE: Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#   False,
#   2.1889677222997326e-10),
#  ('Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#   False,
#   2.1889677222997326e-10)]

# %%
spammiest_hams = list(filter(lambda row: not row[1], classified))
hammiest_spams = list(filter(lambda row: row[1], classified))

print("spammiest_hams",spammiest_hams[-5:])
print("hammiest_spams",hammiest_spams[:5])
# Out:
# spammiest_hams [('Re: [SAtalk] checking out Razor2 (and SA 2.41) install - Net::DNS:Resolver problem?', False, 1.0287954956778856e-09), ('Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41', False, 3.5645248760271325e-10), ('Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False, 2.1889677222997326e-10), ('RE: Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False, 2.1889677222997326e-10), ('Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False, 2.1889677222997326e-10)]
# hammiest_spams [('MSNBC: Rates Hit 18 year Low 4.75% ...28940', True, 0.9999999941001101), ('Last time you spent $25 did u make $100,000,s? Well this time you will. wju', True, 0.999999988485202), ('HOME REPS WANTED-FORTUNE 500 COMP HIRING', True, 0.9999999761928421), ('FORTUNE 500 WORK AT HOME REPS NEEDED!', True, 0.9999998981122058), ('Order your Viagra and weight-loss here 6117kFvc5--9', True, 0.9999998900992519)]
